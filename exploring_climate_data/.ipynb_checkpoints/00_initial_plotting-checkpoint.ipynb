# %% [markdown]
# # initial plotting

# %%
from netCDF4 import Dataset
import xarray as xr
import ipywidgets as widgets
import numpy as np


import matplotlib.pyplot as plt
# %matplotlib inline
import cartopy.crs as ccrs

# %% [markdown]
# ## era5 precipitation data for june 2021

# %%
era5_prec_june_2021 = xr.open_dataset("./data/ERA5_REANALYSIS_precipitation_200306.nc")
print(era5_prec_june_2021)
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 1440, latitude: 721, time: 1)
# Coordinates:
#   * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#   * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#   * time       (time) datetime64[ns] 2021-06-01
# Data variables:
#     tp         (time, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2021-11-29 04:51:39 GMT by grib_to_netcdf-2.23.0: /opt/ecmw...

# %%
print(era5_prec_june_2021['tp'])
# Out:
# <xarray.DataArray 'tp' (time: 1, latitude: 721, longitude: 1440)>
# [1038240 values with dtype=float32]
# Coordinates:
#   * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#   * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#   * time       (time) datetime64[ns] 2021-06-01
# Attributes:
#     units:      m
#     long_name:  Total precipitation

# %%
fig = plt.figure(figsize=[12,5])

#setting vmax to 0.02 to be able show a clearer gradient
era5_prec_june_2021['tp'].plot(cmap='jet', vmax=0.02)

# %%
#spatial information
lats = era5_prec_june_2021.variables['latitude'][:]  
longs = era5_prec_june_2021.variables['longitude'][:]

#temporal information
time = era5_prec_june_2021.variables['time'][:]

#climate variable of interest
tp = era5_prec_june_2021.variables['tp'][:]

# %%
lon, lat = np.meshgrid(longs,lats)

#set the axes' spatial projection, styling, and title
ax = plt.axes(projection=ccrs.PlateCarree())
ax.coastlines()
ax.set_title('precipitation for june, 2021')

# generate the contour map
plt.contourf(longs[0], lats[0], tp[0], 60, transform=ccrs.PlateCarree())
             
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-78084cea2ab8> in <module>()
#       7
#       8 # generate the contour map
# ----> 9 plt.contourf(longs[0], lats[0], tp[0], 60, transform=ccrs.PlateCarree())
#      10
#      11 plt.show()
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in contourf(data, *args, **kwargs)
#    2577     __ret = gca().contourf(
#    2578         *args, **({"data": data} if data is not None else {}),
# -> 2579         **kwargs)
#    2580     if __ret._A is not None: sci(__ret)  # noqa
#    2581     return __ret
#
# /opt/anaconda3/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py in contourf(self, *args, **kwargs)
#    1398                         sub_trans.force_path_ccw = True
#    1399
# -> 1400         result = matplotlib.axes.Axes.contourf(self, *args, **kwargs)
#    1401
#    1402         # We need to compute the dataLim correctly for contours.
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in contourf(self, *args, **kwargs)
#    6333     def contourf(self, *args, **kwargs):
#    6334         kwargs['filled'] = True
# -> 6335         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6336         self._request_autoscale_view()
#    6337         return contours
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, *args, **kwargs)
#     814         self._transform = transform
#     815
# --> 816         kwargs = self._process_args(*args, **kwargs)
#     817         self._process_levels()
#     818
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py in _process_args(self, corner_mask, *args, **kwargs)
#    1428             self._corner_mask = corner_mask
#    1429
# -> 1430             x, y, z = self._contour_args(args, kwargs)
#    1431
#    1432             _mask = ma.getmask(z)
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py in _contour_args(self, args, kwargs)
#    1486             args = args[1:]
#    1487         elif Nargs <= 4:
# -> 1488             x, y, z = self._check_xyz(args[:3], kwargs)
#    1489             args = args[3:]
#    1490         else:
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py in _check_xyz(self, args, kwargs)
#    1544                     f"Shapes of y {y.shape} and z {z.shape} do not match")
#    1545         else:
# -> 1546             raise TypeError(f"Inputs x and y must be 1D or 2D, not {x.ndim}D")
#    1547
#    1548         return x, y, z
#
# TypeError: Inputs x and y must be 1D or 2D, not 0D

# %% [markdown]
# ## era5 temperature data for june 2021

# %%
era5_temp_june_2021 = xr.open_dataset("./data/ERA5_REANALYSIS_air_temperature_200306.nc")
print(era5_temp_june_2021)

# %%
fig = plt.figure(figsize=[12,5])

ax = fig.add_subplot(111, projection=ccrs.PlateCarree(central_longitude=0))

era5_temp_june_2021['d2m'].plot(ax=ax, cmap='jet',
                   transform=ccrs.PlateCarree())

ax.coastlines(color="white")

plt.show()

# %%
fig = plt.figure(figsize=[12,5])

ax = fig.add_subplot(111, projection=ccrs.Orthographic(central_longitude=20, central_latitude=40))

era5_temp_june_2021['d2m'].plot(ax=ax, cmap='jet',
                   transform=ccrs.PlateCarree())

ax.coastlines(color="white")

plt.show()

plt.savefig('era5_temp_june_2021_globe.png', bbox_inches='tight')

# %%
## cmip5 precipitation data for 1850-

# %%
cmip5_prec_historical = xr.open_dataset("./data/pr_Amon_NorESM1-M_historical_r1i1p1_185001-200512.nc")
print(cmip5_prec_historical)

# %%
cmip5_prec_historical["pr"].data = cmip5_prec_historical["pr"].data * 86.4
cmip5_prec_historical["pr"].attrs["units"] = 'm/day'

# %%
fig = plt.figure(figsize=[12,5])

ax = fig.add_subplot(111, projection=ccrs.PlateCarree(central_longitude=0))

cmip5_prec_historical['pr'].sel(time='200306').plot(ax=ax, cmap='jet',
                   transform=ccrs.PlateCarree())

ax.coastlines(color="white")

plt.show()

# %%
select_date = widgets.Dropdown(
    options=cmip5_prec_historical.time.values.tolist(),
    rows=2,
    description='Date:',
    disabled=False
)

def generate_plot(date):
    
    fig = plt.figure(figsize=[12,5])

    ax = fig.add_subplot(111, projection=ccrs.PlateCarree(central_longitude=0))
    
    cmip5_prec_historical['pr'].sel(time=date).plot(cmap='jet', 
                                      transform=ccrs.PlateCarree())
    
    ax.coastlines(color='white', linewidth=1)

interact_plot = widgets.interact(generate_plot, date = select_date);

plt.savefig('cmip5_prec_historical.png', bbox_inches='tight')
